# %% [markdown]
# <a href="https://colab.research.google.com/github/naarayanareddyhema-dev/Syntecxhub_project3_titanic_dataset_EDA/blob/main/Syntecxhub_project3_titanic_dataset_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  Titanic Dataset – Exploratory Data Analysis (EDA)

# %% [markdown]
# Objective
#
# The objective of this project is to analyze the Titanic dataset and discover patterns related to passenger survival using Exploratory Data Analysis (EDA).

# %% [markdown]
# -> Dataset Information
#
# The Titanic dataset contains information about passengers such as:
#
# Age
#
# Gender
#
# Passenger class
#
# Fare
#
# Survival status
#
# Target variable: Survived
# (0 = Not Survived, 1 = Survived)

# %% [markdown]
# step 1:libraries used

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# step2:load the dataset

# %%
df = sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# Output Description:
# The output shows details of Titanic passengers such as:
# survived – whether the passenger survived (0 = No, 1 = Yes)
# pclass – passenger class (1st, 2nd, 3rd)
# sex – gender of the passenger
# age – age of the passenger
# fare – ticket fare
# embarked – port of embarkation

# %% [markdown]
# Basic information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
#  Output:
#
# Shows:
#
# Mean age ≈ 29
#
# Average fare ≈ 32
#
# Min, max, quartiles for numerical columns

# %% [markdown]
# step 3: Missing Values Analysis

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# step 4: Handling Missing Values

# %%
df['age'].mean()
mean_age = df['age'].mean()
df['age'] = df['age'].fillna(mean_age)
df['age'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# step 5:Survival Count

# %%
sns.countplot(x='sex', hue='survived', data=df)
plt.title("Survival by Gender")
plt.show()

# %% [markdown]
# step 6: Survival by Passenger Class

# %%
df['survived'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%',
    labels=['Died', 'Survived']
)

plt.title("Survival Distribution")
plt.ylabel("")
plt.show()

# %% [markdown]
# Step 7: Survival by Gender

# %%
sns.countplot(x='sex', hue='survived', data=df)
plt.title("Survival by Gender")
plt.show()

# %% [markdown]
# Step 8: Survival by Passenger Class

# %%
sns.countplot(x='pclass', hue='survived', data=df)
plt.title("Survival by Passenger Class")
plt.show()

# %% [markdown]
# Step 9: Age Distribution

# %%
sns.histplot(df['age'], kde=True)
plt.title("Age Distribution")
plt.show()

# %% [markdown]
# Step 10: Correlation Heatmap

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Observation:
#
# 1.Fare positively correlated with survival.
#
# 2.Pclass negatively correlated with survival.

# %% [markdown]
# Final Observationsand Project Conclusion::
#
# 1.Females had higher survival rate.
#
# 2.First class passengers survived more.
#
# 3.Higher fare passengers survived more.
#
# 4.Age has slight impact.
#
# 5.Majority passengers were young adults.
